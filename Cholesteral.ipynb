# %%
library(tidyverse)
library(repr)
library(tidymodels)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# ── Attaching packages ────────────────────────────────────── tidymodels 1.0.0 ──
#
# ✔ broom        1.0.0     ✔ rsample      1.0.0
# ✔ dials        1.0.0     ✔ tune         1.0.0
# ✔ infer        1.0.2     ✔ workflows    1.0.0
# ✔ modeldata    1.0.0     ✔ workflowsets 1.0.0
# ✔ parsnip      1.0.0     ✔ yardstick    1.0.0
# ✔ recipes      1.0.1
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()
# • Use suppressPackageStartupMessages() to eliminate package startup messages

# %%
data <- read_table("https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/cleve.mod", skip = 19, col_names=FALSE) 
colnames(data) <- c("age", "sex", "chest_pain_type", "resting_blood_pres", "cholesteral", "fasting_blood_sugar < 120", "resting_ecg", "max_heart_rate", "exercise_induced_angina", "oldpeak", "slope", "number_of_vessels_colored", "thal", "healthy_or_sick", "sickness_classifier")
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   X1 = col_double(),
#   X2 = col_character(),
#   X3 = col_character(),
#   X4 = col_double(),
#   X5 = col_double(),
#   X6 = col_character(),
#   X7 = col_character(),
#   X8 = col_double(),
#   X9 = col_character(),
#   X10 = col_double(),
#   X11 = col_character(),
#   X12 = col_character(),
#   X13 = col_character(),
#   X14 = col_character(),
#   X15 = col_character()
# )

# %%
data
# Out:
#     age sex  chest_pain_type resting_blood_pres cholesteral
# 1   63  male angina          145                233
# 2   67  male asympt          160                286
# 3   67  male asympt          120                229
# 4   37  male notang          130                250
# 5   41  fem  abnang          130                204
# 6   56  male abnang          120                236
# 7   62  fem  asympt          140                268
# 8   57  fem  asympt          120                354
# 9   63  male asympt          130                254
# 10  53  male asympt          140                203
# 11  57  male asympt          140                192
# 12  56  fem  abnang          140                294
# 13  56  male notang          130                256
# 14  44  male abnang          120                263
# 15  49  male abnang          130                266
# 16  64  male angina          110                211
# 17  58  fem  angina          150                283
# 18  58  male abnang          120                284
# 19  58  male notang          132                224
# 20  60  male asympt          130                206
# 21  50  fem  notang          120                219
# 22  58  fem  notang          120                340
# 23  66  fem  angina          150                226
# 24  43  male asympt          150                247
# 25  40  male asympt          110                167
# 26  69  fem  angina          140                239
# 27  60  male asympt          117                230
# 28  64  male notang          140                335
# 29  59  male asympt          135                234
# 30  44  male notang          130                233
# ⋮   ⋮   ⋮    ⋮               ⋮                  ⋮
# 274 57  fem  asympt          128                303
# 275 71  fem  notang          110                265
# 276 49  male notang          120                188
# 277 54  male abnang          108                309
# 278 59  male asympt          140                177
# 279 57  male notang          128                229
# 280 65  male angina          138                282
# 281 45  fem  abnang          130                234
# 282 56  fem  asympt          200                288
# 283 54  male asympt          110                239
# 284 44  male abnang          120                220
# 285 62  fem  asympt          124                209
# 286 54  male notang          120                258
# 287 51  male notang           94                227
# 288 44  fem  notang          118                242
# 289 58  fem  abnang          136                319
# 290 60  fem  angina          150                240
# 291 44  male notang          120                226
# 292 61  male asympt          138                166
# 293 42  male asympt          136                315
# 294 68  male notang          118                277
# 295 46  male abnang          101                197
# 296 77  male asympt          125                304
# 297 54  fem  notang          110                214
# 298 58  fem  asympt          100                248
# 299 48  male notang          124                255
# 300 57  male asympt          132                207
# 301 49  male notang          118                149
# 302 74  fem  abnang          120                269
# 303 54  fem  notang          160                201
#     fasting_blood_sugar < 120 resting_ecg max_heart_rate
# 1   true                      hyp         150
# 2   fal                       hyp         108
# 3   fal                       hyp         129
# 4   fal                       norm        187
# 5   fal                       hyp         172
# 6   fal                       norm        178
# 7   fal                       hyp         160
# 8   fal                       norm        163
# 9   fal                       hyp         147
# 10  true                      hyp         155
# 11  fal                       norm        148
# 12  fal                       hyp         153
# 13  true                      hyp         142
# 14  fal                       norm        173
# 15  fal                       norm        171
# 16  fal                       hyp         144
# 17  true                      hyp         162
# 18  fal                       hyp         160
# 19  fal                       hyp         173
# 20  fal                       hyp         132
# 21  fal                       norm        158
# 22  fal                       norm        172
# 23  fal                       norm        114
# 24  fal                       norm        171
# 25  fal                       hyp         114
# 26  fal                       norm        151
# 27  true                      norm        160
# 28  fal                       norm        158
# 29  fal                       norm        161
# 30  fal                       norm        179
# ⋮   ⋮                         ⋮           ⋮
# 274 fal                       hyp         159
# 275 true                      hyp         130
# 276 fal                       norm        139
# 277 fal                       norm        156
# 278 fal                       norm        162
# 279 fal                       hyp         150
# 280 true                      hyp         174
# 281 fal                       hyp         175
# 282 true                      hyp         133
# 283 fal                       norm        126
# 284 fal                       norm        170
# 285 fal                       norm        163
# 286 fal                       hyp         147
# 287 fal                       norm        154
# 288 fal                       norm        149
# 289 true                      hyp         152
# 290 fal                       norm        171
# 291 fal                       norm        169
# 292 fal                       hyp         125
# 293 fal                       norm        125
# 294 fal                       norm        151
# 295 true                      norm        156
# 296 fal                       hyp         162
# 297 fal                       norm        158
# 298 fal                       hyp         122
# 299 true                      norm        175
# 300 fal                       norm        168
# 301 fal                       hyp         126
# 302 fal                       hyp         121
# 303 fal                       norm        163
#     exercise_induced_angina oldpeak slope number_of_vessels_colored thal
# 1   fal                     2.3     down  0.0                       fix
# 2   true                    1.5     flat  3.0                       norm
# 3   true                    2.6     flat  2.0                       rev
# 4   fal                     3.5     down  0.0                       norm
# 5   fal                     1.4     up    0.0                       norm
# 6   fal                     0.8     up    0.0                       norm
# 7   fal                     3.6     down  2.0                       norm
# 8   true                    0.6     up    0.0                       norm
# 9   fal                     1.4     flat  1.0                       rev
# 10  true                    3.1     down  0.0                       rev
# 11  fal                     0.4     flat  0.0                       fix
# 12  fal                     1.3     flat  0.0                       norm
# 13  true                    0.6     flat  1.0                       fix
# 14  fal                     0.0     up    0.0                       rev
# 15  fal                     0.6     up    0.0                       norm
# 16  true                    1.8     flat  0.0                       norm
# 17  fal                     1.0     up    0.0                       norm
# 18  fal                     1.8     flat  0.0                       norm
# 19  fal                     3.2     up    2.0                       rev
# 20  true                    2.4     flat  2.0                       rev
# 21  fal                     1.6     flat  0.0                       norm
# 22  fal                     0.0     up    0.0                       norm
# 23  fal                     2.6     down  0.0                       norm
# 24  fal                     1.5     up    0.0                       norm
# 25  true                    2.0     flat  0.0                       rev
# 26  fal                     1.8     up    2.0                       norm
# 27  true                    1.4     up    2.0                       rev
# 28  fal                     0.0     up    0.0                       norm
# 29  fal                     0.5     flat  0.0                       rev
# 30  true                    0.4     up    0.0                       norm
# ⋮   ⋮                       ⋮       ⋮     ⋮                         ⋮
# 274 fal                     0.0     up    1.0                       norm
# 275 fal                     0.0     up    1.0                       norm
# 276 fal                     2.0     flat  3.0                       rev
# 277 fal                     0.0     up    0.0                       rev
# 278 true                    0.0     up    1.0                       rev
# 279 fal                     0.4     flat  1.0                       rev
# 280 fal                     1.4     flat  1.0                       norm
# 281 fal                     0.6     flat  0.0                       norm
# 282 true                    4.0     down  2.0                       rev
# 283 true                    2.8     flat  1.0                       rev
# 284 fal                     0.0     up    0.0                       norm
# 285 fal                     0.0     up    0.0                       norm
# 286 fal                     0.4     flat  0.0                       rev
# 287 true                    0.0     up    1.0                       rev
# 288 fal                     0.3     flat  1.0                       norm
# 289 fal                     0.0     up    2.0                       norm
# 290 fal                     0.9     up    0.0                       norm
# 291 fal                     0.0     up    0.0                       norm
# 292 true                    3.6     flat  1.0                       norm
# 293 true                    1.8     flat  0.0                       fix
# 294 fal                     1.0     up    1.0                       rev
# 295 fal                     0.0     up    0.0                       rev
# 296 true                    0.0     up    3.0                       norm
# 297 fal                     1.6     flat  0.0                       norm
# 298 fal                     1.0     flat  0.0                       norm
# 299 fal                     0.0     up    2.0                       norm
# 300 true                    0.0     up    0.0                       rev
# 301 fal                     0.8     up    3.0                       norm
# 302 true                    0.2     up    1.0                       norm
# 303 fal                     0.0     up    1.0                       norm
#     healthy_or_sick sickness_classifier
# 1   buff            H
# 2   sick            S2
# 3   sick            S1
# 4   buff            H
# 5   buff            H
# 6   buff            H
# 7   sick            S3
# 8   buff            H
# 9   sick            S2
# 10  sick            S1
# 11  buff            H
# 12  buff            H
# 13  sick            S2
# 14  buff            H
# 15  buff            H
# 16  buff            H
# 17  buff            H
# 18  sick            S1
# 19  sick            S3
# 20  sick            S4
# 21  buff            H
# 22  buff            H
# 23  buff            H
# 24  buff            H
# 25  sick            S3
# 26  buff            H
# 27  sick            S2
# 28  sick            S1
# 29  buff            H
# 30  buff            H
# ⋮   ⋮               ⋮
# 274 buff            H
# 275 buff            H
# 276 sick            S3
# 277 buff            H
# 278 sick            S2
# 279 sick            S1
# 280 sick            S1
# 281 buff            H
# 282 sick            S3
# 283 sick            S3
# 284 buff            H
# 285 buff            H
# 286 buff            H
# 287 buff            H
# 288 buff            H
# 289 sick            S3
# 290 buff            H
# 291 buff            H
# 292 sick            S4
# 293 sick            S2
# 294 buff            H
# 295 buff            H
# 296 sick            S4
# 297 buff            H
# 298 buff            H
# 299 buff            H
# 300 buff            H
# 301 sick            S1
# 302 buff            H
# 303 buff            H

# %%
data_selected <- data |>
    select("age", "resting_blood_pres", "cholesteral", "max_heart_rate", "oldpeak", "number_of_vessels_colored", "healthy_or_sick", "sickness_classifier")

data_selected
# Out:
#     age resting_blood_pres cholesteral max_heart_rate oldpeak
# 1   63  145                233         150            2.3
# 2   67  160                286         108            1.5
# 3   67  120                229         129            2.6
# 4   37  130                250         187            3.5
# 5   41  130                204         172            1.4
# 6   56  120                236         178            0.8
# 7   62  140                268         160            3.6
# 8   57  120                354         163            0.6
# 9   63  130                254         147            1.4
# 10  53  140                203         155            3.1
# 11  57  140                192         148            0.4
# 12  56  140                294         153            1.3
# 13  56  130                256         142            0.6
# 14  44  120                263         173            0.0
# 15  49  130                266         171            0.6
# 16  64  110                211         144            1.8
# 17  58  150                283         162            1.0
# 18  58  120                284         160            1.8
# 19  58  132                224         173            3.2
# 20  60  130                206         132            2.4
# 21  50  120                219         158            1.6
# 22  58  120                340         172            0.0
# 23  66  150                226         114            2.6
# 24  43  150                247         171            1.5
# 25  40  110                167         114            2.0
# 26  69  140                239         151            1.8
# 27  60  117                230         160            1.4
# 28  64  140                335         158            0.0
# 29  59  135                234         161            0.5
# 30  44  130                233         179            0.4
# ⋮   ⋮   ⋮                  ⋮           ⋮              ⋮
# 274 57  128                303         159            0.0
# 275 71  110                265         130            0.0
# 276 49  120                188         139            2.0
# 277 54  108                309         156            0.0
# 278 59  140                177         162            0.0
# 279 57  128                229         150            0.4
# 280 65  138                282         174            1.4
# 281 45  130                234         175            0.6
# 282 56  200                288         133            4.0
# 283 54  110                239         126            2.8
# 284 44  120                220         170            0.0
# 285 62  124                209         163            0.0
# 286 54  120                258         147            0.4
# 287 51   94                227         154            0.0
# 288 44  118                242         149            0.3
# 289 58  136                319         152            0.0
# 290 60  150                240         171            0.9
# 291 44  120                226         169            0.0
# 292 61  138                166         125            3.6
# 293 42  136                315         125            1.8
# 294 68  118                277         151            1.0
# 295 46  101                197         156            0.0
# 296 77  125                304         162            0.0
# 297 54  110                214         158            1.6
# 298 58  100                248         122            1.0
# 299 48  124                255         175            0.0
# 300 57  132                207         168            0.0
# 301 49  118                149         126            0.8
# 302 74  120                269         121            0.2
# 303 54  160                201         163            0.0
#     number_of_vessels_colored healthy_or_sick sickness_classifier
# 1   0.0                       buff            H
# 2   3.0                       sick            S2
# 3   2.0                       sick            S1
# 4   0.0                       buff            H
# 5   0.0                       buff            H
# 6   0.0                       buff            H
# 7   2.0                       sick            S3
# 8   0.0                       buff            H
# 9   1.0                       sick            S2
# 10  0.0                       sick            S1
# 11  0.0                       buff            H
# 12  0.0                       buff            H
# 13  1.0                       sick            S2
# 14  0.0                       buff            H
# 15  0.0                       buff            H
# 16  0.0                       buff            H
# 17  0.0                       buff            H
# 18  0.0                       sick            S1
# 19  2.0                       sick            S3
# 20  2.0                       sick            S4
# 21  0.0                       buff            H
# 22  0.0                       buff            H
# 23  0.0                       buff            H
# 24  0.0                       buff            H
# 25  0.0                       sick            S3
# 26  2.0                       buff            H
# 27  2.0                       sick            S2
# 28  0.0                       sick            S1
# 29  0.0                       buff            H
# 30  0.0                       buff            H
# ⋮   ⋮                         ⋮               ⋮
# 274 1.0                       buff            H
# 275 1.0                       buff            H
# 276 3.0                       sick            S3
# 277 0.0                       buff            H
# 278 1.0                       sick            S2
# 279 1.0                       sick            S1
# 280 1.0                       sick            S1
# 281 0.0                       buff            H
# 282 2.0                       sick            S3
# 283 1.0                       sick            S3
# 284 0.0                       buff            H
# 285 0.0                       buff            H
# 286 0.0                       buff            H
# 287 1.0                       buff            H
# 288 1.0                       buff            H
# 289 2.0                       sick            S3
# 290 0.0                       buff            H
# 291 0.0                       buff            H
# 292 1.0                       sick            S4
# 293 0.0                       sick            S2
# 294 1.0                       buff            H
# 295 0.0                       buff            H
# 296 3.0                       sick            S4
# 297 0.0                       buff            H
# 298 0.0                       buff            H
# 299 2.0                       buff            H
# 300 0.0                       buff            H
# 301 3.0                       sick            S1
# 302 1.0                       buff            H
# 303 1.0                       buff            H

# %%
data_cholesteral <- data_selected |>
    select(cholesteral, healthy_or_sick)

data_cholesteral
# Out:
#     cholesteral healthy_or_sick
# 1   233         buff
# 2   286         sick
# 3   229         sick
# 4   250         buff
# 5   204         buff
# 6   236         buff
# 7   268         sick
# 8   354         buff
# 9   254         sick
# 10  203         sick
# 11  192         buff
# 12  294         buff
# 13  256         sick
# 14  263         buff
# 15  266         buff
# 16  211         buff
# 17  283         buff
# 18  284         sick
# 19  224         sick
# 20  206         sick
# 21  219         buff
# 22  340         buff
# 23  226         buff
# 24  247         buff
# 25  167         sick
# 26  239         buff
# 27  230         sick
# 28  335         sick
# 29  234         buff
# 30  233         buff
# ⋮   ⋮           ⋮
# 274 303         buff
# 275 265         buff
# 276 188         sick
# 277 309         buff
# 278 177         sick
# 279 229         sick
# 280 282         sick
# 281 234         buff
# 282 288         sick
# 283 239         sick
# 284 220         buff
# 285 209         buff
# 286 258         buff
# 287 227         buff
# 288 242         buff
# 289 319         sick
# 290 240         buff
# 291 226         buff
# 292 166         sick
# 293 315         sick
# 294 277         buff
# 295 197         buff
# 296 304         sick
# 297 214         buff
# 298 248         buff
# 299 255         buff
# 300 207         buff
# 301 149         sick
# 302 269         buff
# 303 201         buff

# %%
plot_cholesteral <- data_cholesteral |>
    ggplot(aes(x = cholesteral, fill = healthy_or_sick)) +
    geom_histogram() +
    labs(x = "Cholesteral", y = "# of Healthy Or Sick") +
    theme(text = element_text(size = 20))

plot_cholesteral
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
